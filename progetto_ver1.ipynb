# %% [markdown]
# **1) Normalize the loan_lenders table. In the normalized table, each row must have one loan_id and one lender.**

# %%
import pandas as pd

# %%
import numpy as np

# %%
import datetime

# %%
pd.options.display.max_columns = None

# %%
loan_lenders_file=pd.read_csv("Files/loans_lenders.csv")

# %%
loan_lenders_file['lenders'] = loan_lenders_file['lenders'].str.split(', ')

# %%
loan_lenders=loan_lenders_file.explode('lenders').reset_index(drop=True)

# %%
loan_lenders
# Out:
#           loan_id            lenders
# 0          483693             muc888
# 1          483693            sam4326
# 2          483693        camaran3922
# 3          483693        lachheb1865
# 4          483693        rebecca3499
# ...           ...                ...
# 28293926  1206425  trogdorfamily7622
# 28293927  1206425          danny6470
# 28293928  1206425            don6118
# 28293929  1206486           alan5175
# 28293930  1206486        amy38101311
#
# [28293931 rows x 2 columns]

# %% [markdown]
# **2) For each loan, add a column duration corresponding to the number of days between the disburse time and the planned expiration time. If any of those two dates is missing, also the duration must be missing.**

# %%
loans=pd.read_csv("Files/loans.csv",parse_dates=['disburse_time','planned_expiration_time'])

# %%
loans
# Out:
#          loan_id           loan_name original_language  \
# 0         657307                Aivy           English
# 1         657259      Idalia Marizza           Spanish
# 2         658010               Aasia           English
# 3         659347             Gulmira           Russian
# 4         656933             Ricky\t           English
# ...          ...                 ...               ...
# 1419602   988180                 NaN               NaN
# 1419603   988213             Perlita           English
# 1419604   989109  Okyeso Nyame Group           English
# 1419605   989143            Exequila           English
# 1419606   989240               Lydia            French
#
#                                                description  \
# 0        Aivy, 21 years of age, is single and lives in ...
# 1        Doña Idalia, esta casada, tiene 57 años de eda...
# 2        Aasia is a 45-year-old married lady and she ha...
# 3        Гулмире 36 лет, замужем, вместе с супругом вос...
# 4        Ricky is a farmer who currently cultivates his...
# ...                                                    ...
# 1419602                                                NaN
# 1419603  Perlita is 52 years old, married and has three...
# 1419604  Okyeso Nyame group will begin its third cycle ...
# 1419605  Exequila  is from San Miguel, Bohol. She is in...
# 1419606  Lydia a 37ans et habite dans une zone rurale. ...
#
#                                     description_translated  funded_amount  \
# 0                                                      NaN          125.0
# 1        Idalia, 57, is married and lives with her husb...          400.0
# 2                                                      NaN          400.0
# 3        Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                      NaN          425.0
# ...                                                    ...            ...
# 1419602                                                NaN          400.0
# 1419603  Perlita is 52 years old, married and has three...          300.0
# 1419604  Okyeso Nyame group will begin its third cycle ...         2425.0
# 1419605  Exequila  is from San Miguel, Bohol. She is in...          100.0
# 1419606  Lydia is 37 years old and lives in a rural are...          175.0
#
#          loan_amount  status  activity_name  sector_name  \
# 0              125.0  funded  General Store       Retail
# 1              400.0  funded  Used Clothing     Clothing
# 2              400.0  funded  General Store       Retail
# 3              625.0  funded        Farming  Agriculture
# 4              425.0  funded        Farming  Agriculture
# ...              ...     ...            ...          ...
# 1419602        400.0  funded      Tailoring     Services
# 1419603        300.0  funded           Pigs  Agriculture
# 1419604       2425.0  funded         Bakery         Food
# 1419605        100.0  funded        Farming  Agriculture
# 1419606        175.0  funded         Sewing     Services
#
#                                                   loan_use country_code  \
# 0         to buy additional inventories for her sari-sa...           PH
# 1        To buy American clothing such as blouses, shir...           HN
# 2                    to buy stock of rice, sugar and flour           PK
# 3        to buy cucumber and tomato seeds, as well as f...           KG
# 4         to buy organic fertilizer and agrochemical pr...           PH
# ...                                                    ...          ...
# 1419602                                                NaN           KE
# 1419603  to buy feeds and other supplies to raise her pigs           PH
# 1419604  to buy margarine, flour and sugar at wholesale...           GH
# 1419605                            to buy feed and piglets           PH
# 1419606  to buy a sewing machine, a sewing machine moto...           MG
#
#         country_name                       town_name currency_policy  \
# 0        Philippines            Ozamiz - Ozamiz City          shared
# 1           Honduras               La Lopez, Choloma          shared
# 2           Pakistan                       Lala Musa          shared
# 3         Kyrgyzstan      Aravan village, Osh region          shared
# 4        Philippines  Baleleng, Sto. Thomas, Isabela          shared
# ...              ...                             ...             ...
# 1419602        Kenya                             NaN          shared
# 1419603  Philippines                 Numancia, Aklan          shared
# 1419604        Ghana                         Chorkor          shared
# 1419605  Philippines               San Miguel, Bohol          shared
# 1419606   Madagascar                    Antananarivo          shared
#
#          currency_exchange_coverage_rate currency  partner_id  \
# 0                                    0.1      PHP       126.0
# 1                                    0.1      HNL       201.0
# 2                                    0.1      PKR       245.0
# 3                                    0.1      KGS       171.0
# 4                                    0.1      PHP       123.0
# ...                                  ...      ...         ...
# 1419602                              0.1      KES       138.0
# 1419603                              0.1      PHP       145.0
# 1419604                              0.1      GHS       231.0
# 1419605                              0.1      PHP       125.0
# 1419606                              0.1      MGA       443.0
#
#                            posted_time   planned_expiration_time  \
# 0        2014-01-15 02:23:45.000 +0000 2014-02-14 03:30:06+00:00
# 1        2014-01-14 20:23:20.000 +0000 2014-03-26 22:25:07+00:00
# 2        2014-01-16 11:32:58.000 +0000 2014-02-15 21:10:05+00:00
# 3        2014-01-20 09:59:48.000 +0000 2014-02-21 03:10:02+00:00
# 4        2014-01-14 05:46:21.000 +0000 2014-02-13 06:10:02+00:00
# ...                                ...                       ...
# 1419602  2015-12-01 04:49:50.000 +0000 2016-01-02 01:00:03+00:00
# 1419603  2015-12-01 05:13:30.000 +0000 2016-01-02 16:40:07+00:00
# 1419604  2015-12-02 10:56:28.000 +0000 2016-01-03 22:20:04+00:00
# 1419605  2015-12-02 11:41:46.000 +0000 2016-01-05 08:50:02+00:00
# 1419606  2015-12-02 13:55:07.000 +0000 2016-01-03 20:50:06+00:00
#
#                     disburse_time                    raised_time  lender_term  \
# 0       2013-12-22 08:00:00+00:00  2014-01-15 04:48:22.000 +0000          7.0
# 1       2013-12-20 08:00:00+00:00  2014-02-25 06:42:06.000 +0000          8.0
# 2       2014-01-09 08:00:00+00:00  2014-01-24 23:06:18.000 +0000         14.0
# 3       2014-01-17 08:00:00+00:00  2014-01-22 05:29:28.000 +0000         14.0
# 4       2013-12-17 08:00:00+00:00  2014-01-14 17:29:27.000 +0000          7.0
# ...                           ...                            ...          ...
# 1419602 2015-11-23 08:00:00+00:00  2015-12-28 15:44:18.000 +0000         14.0
# 1419603 2015-11-24 08:00:00+00:00  2015-12-22 10:37:06.000 +0000         14.0
# 1419604 2015-11-13 08:00:00+00:00  2015-12-26 20:24:47.000 +0000          8.0
# 1419605 2015-11-03 08:00:00+00:00  2015-12-06 21:03:57.000 +0000         12.0
# 1419606 2015-11-03 08:00:00+00:00  2015-12-04 23:17:04.000 +0000         14.0
#
#          num_lenders_total  num_journal_entries  num_bulk_entries  \
# 0                        3                    2                 1
# 1                       11                    2                 1
# 2                       16                    2                 1
# 3                       21                    2                 1
# 4                       15                    2                 1
# ...                    ...                  ...               ...
# 1419602                 16                    4                 2
# 1419603                 12                    1                 1
# 1419604                 76                    2                 1
# 1419605                  3                    1                 1
# 1419606                  7                    1                 1
#
#                                                       tags  \
# 0                                                      NaN
# 1                                                      NaN
# 2        #Woman Owned Biz, #Supporting Family, user_fav...
# 3                                            user_favorite
# 4                 #Animals, #Eco-friendly, #Sustainable Ag
# ...                                                    ...
# 1419602        #Parent, #Repeat Borrower, #Woman Owned Biz
# 1419603  #Animals, #Elderly, #Repeat Borrower, #Woman O...
# 1419604  user_favorite, #Parent, #Vegan, #Woman Owned B...
# 1419605                                                NaN
# 1419606                                                NaN
#
#                                    borrower_genders  \
# 0                                            female
# 1                                            female
# 2                                            female
# 3                                            female
# 4                                              male
# ...                                             ...
# 1419602                                         NaN
# 1419603                                      female
# 1419604  female, female, female, male, male, female
# 1419605                                      female
# 1419606                                      female
#
#                           borrower_pictured repayment_interval  \
# 0                                      true          irregular
# 1                                      true            monthly
# 2                                      true            monthly
# 3                                      true            monthly
# 4                                      true             bullet
# ...                                     ...                ...
# 1419602                                 NaN            monthly
# 1419603                                true          irregular
# 1419604  true, true, true, true, true, true          irregular
# 1419605                                true          irregular
# 1419606                                true            monthly
#
#         distribution_model
# 0            field_partner
# 1            field_partner
# 2            field_partner
# 3            field_partner
# 4            field_partner
# ...                    ...
# 1419602      field_partner
# 1419603      field_partner
# 1419604      field_partner
# 1419605      field_partner
# 1419606      field_partner
#
# [1419607 rows x 31 columns]

# %%
loans['duration']=(loans['planned_expiration_time']-loans['disburse_time']).dt.days.astype('Int64')

# %%
loans
# Out:
#          loan_id           loan_name original_language  \
# 0         657307                Aivy           English
# 1         657259      Idalia Marizza           Spanish
# 2         658010               Aasia           English
# 3         659347             Gulmira           Russian
# 4         656933             Ricky\t           English
# ...          ...                 ...               ...
# 1419602   988180                 NaN               NaN
# 1419603   988213             Perlita           English
# 1419604   989109  Okyeso Nyame Group           English
# 1419605   989143            Exequila           English
# 1419606   989240               Lydia            French
#
#                                                description  \
# 0        Aivy, 21 years of age, is single and lives in ...
# 1        Doña Idalia, esta casada, tiene 57 años de eda...
# 2        Aasia is a 45-year-old married lady and she ha...
# 3        Гулмире 36 лет, замужем, вместе с супругом вос...
# 4        Ricky is a farmer who currently cultivates his...
# ...                                                    ...
# 1419602                                                NaN
# 1419603  Perlita is 52 years old, married and has three...
# 1419604  Okyeso Nyame group will begin its third cycle ...
# 1419605  Exequila  is from San Miguel, Bohol. She is in...
# 1419606  Lydia a 37ans et habite dans une zone rurale. ...
#
#                                     description_translated  funded_amount  \
# 0                                                      NaN          125.0
# 1        Idalia, 57, is married and lives with her husb...          400.0
# 2                                                      NaN          400.0
# 3        Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                      NaN          425.0
# ...                                                    ...            ...
# 1419602                                                NaN          400.0
# 1419603  Perlita is 52 years old, married and has three...          300.0
# 1419604  Okyeso Nyame group will begin its third cycle ...         2425.0
# 1419605  Exequila  is from San Miguel, Bohol. She is in...          100.0
# 1419606  Lydia is 37 years old and lives in a rural are...          175.0
#
#          loan_amount  status  activity_name  sector_name  \
# 0              125.0  funded  General Store       Retail
# 1              400.0  funded  Used Clothing     Clothing
# 2              400.0  funded  General Store       Retail
# 3              625.0  funded        Farming  Agriculture
# 4              425.0  funded        Farming  Agriculture
# ...              ...     ...            ...          ...
# 1419602        400.0  funded      Tailoring     Services
# 1419603        300.0  funded           Pigs  Agriculture
# 1419604       2425.0  funded         Bakery         Food
# 1419605        100.0  funded        Farming  Agriculture
# 1419606        175.0  funded         Sewing     Services
#
#                                                   loan_use country_code  \
# 0         to buy additional inventories for her sari-sa...           PH
# 1        To buy American clothing such as blouses, shir...           HN
# 2                    to buy stock of rice, sugar and flour           PK
# 3        to buy cucumber and tomato seeds, as well as f...           KG
# 4         to buy organic fertilizer and agrochemical pr...           PH
# ...                                                    ...          ...
# 1419602                                                NaN           KE
# 1419603  to buy feeds and other supplies to raise her pigs           PH
# 1419604  to buy margarine, flour and sugar at wholesale...           GH
# 1419605                            to buy feed and piglets           PH
# 1419606  to buy a sewing machine, a sewing machine moto...           MG
#
#         country_name                       town_name currency_policy  \
# 0        Philippines            Ozamiz - Ozamiz City          shared
# 1           Honduras               La Lopez, Choloma          shared
# 2           Pakistan                       Lala Musa          shared
# 3         Kyrgyzstan      Aravan village, Osh region          shared
# 4        Philippines  Baleleng, Sto. Thomas, Isabela          shared
# ...              ...                             ...             ...
# 1419602        Kenya                             NaN          shared
# 1419603  Philippines                 Numancia, Aklan          shared
# 1419604        Ghana                         Chorkor          shared
# 1419605  Philippines               San Miguel, Bohol          shared
# 1419606   Madagascar                    Antananarivo          shared
#
#          currency_exchange_coverage_rate currency  partner_id  \
# 0                                    0.1      PHP       126.0
# 1                                    0.1      HNL       201.0
# 2                                    0.1      PKR       245.0
# 3                                    0.1      KGS       171.0
# 4                                    0.1      PHP       123.0
# ...                                  ...      ...         ...
# 1419602                              0.1      KES       138.0
# 1419603                              0.1      PHP       145.0
# 1419604                              0.1      GHS       231.0
# 1419605                              0.1      PHP       125.0
# 1419606                              0.1      MGA       443.0
#
#                            posted_time   planned_expiration_time  \
# 0        2014-01-15 02:23:45.000 +0000 2014-02-14 03:30:06+00:00
# 1        2014-01-14 20:23:20.000 +0000 2014-03-26 22:25:07+00:00
# 2        2014-01-16 11:32:58.000 +0000 2014-02-15 21:10:05+00:00
# 3        2014-01-20 09:59:48.000 +0000 2014-02-21 03:10:02+00:00
# 4        2014-01-14 05:46:21.000 +0000 2014-02-13 06:10:02+00:00
# ...                                ...                       ...
# 1419602  2015-12-01 04:49:50.000 +0000 2016-01-02 01:00:03+00:00
# 1419603  2015-12-01 05:13:30.000 +0000 2016-01-02 16:40:07+00:00
# 1419604  2015-12-02 10:56:28.000 +0000 2016-01-03 22:20:04+00:00
# 1419605  2015-12-02 11:41:46.000 +0000 2016-01-05 08:50:02+00:00
# 1419606  2015-12-02 13:55:07.000 +0000 2016-01-03 20:50:06+00:00
#
#                     disburse_time                    raised_time  lender_term  \
# 0       2013-12-22 08:00:00+00:00  2014-01-15 04:48:22.000 +0000          7.0
# 1       2013-12-20 08:00:00+00:00  2014-02-25 06:42:06.000 +0000          8.0
# 2       2014-01-09 08:00:00+00:00  2014-01-24 23:06:18.000 +0000         14.0
# 3       2014-01-17 08:00:00+00:00  2014-01-22 05:29:28.000 +0000         14.0
# 4       2013-12-17 08:00:00+00:00  2014-01-14 17:29:27.000 +0000          7.0
# ...                           ...                            ...          ...
# 1419602 2015-11-23 08:00:00+00:00  2015-12-28 15:44:18.000 +0000         14.0
# 1419603 2015-11-24 08:00:00+00:00  2015-12-22 10:37:06.000 +0000         14.0
# 1419604 2015-11-13 08:00:00+00:00  2015-12-26 20:24:47.000 +0000          8.0
# 1419605 2015-11-03 08:00:00+00:00  2015-12-06 21:03:57.000 +0000         12.0
# 1419606 2015-11-03 08:00:00+00:00  2015-12-04 23:17:04.000 +0000         14.0
#
#          num_lenders_total  num_journal_entries  num_bulk_entries  \
# 0                        3                    2                 1
# 1                       11                    2                 1
# 2                       16                    2                 1
# 3                       21                    2                 1
# 4                       15                    2                 1
# ...                    ...                  ...               ...
# 1419602                 16                    4                 2
# 1419603                 12                    1                 1
# 1419604                 76                    2                 1
# 1419605                  3                    1                 1
# 1419606                  7                    1                 1
#
#                                                       tags  \
# 0                                                      NaN
# 1                                                      NaN
# 2        #Woman Owned Biz, #Supporting Family, user_fav...
# 3                                            user_favorite
# 4                 #Animals, #Eco-friendly, #Sustainable Ag
# ...                                                    ...
# 1419602        #Parent, #Repeat Borrower, #Woman Owned Biz
# 1419603  #Animals, #Elderly, #Repeat Borrower, #Woman O...
# 1419604  user_favorite, #Parent, #Vegan, #Woman Owned B...
# 1419605                                                NaN
# 1419606                                                NaN
#
#                                    borrower_genders  \
# 0                                            female
# 1                                            female
# 2                                            female
# 3                                            female
# 4                                              male
# ...                                             ...
# 1419602                                         NaN
# 1419603                                      female
# 1419604  female, female, female, male, male, female
# 1419605                                      female
# 1419606                                      female
#
#                           borrower_pictured repayment_interval  \
# 0                                      true          irregular
# 1                                      true            monthly
# 2                                      true            monthly
# 3                                      true            monthly
# 4                                      true             bullet
# ...                                     ...                ...
# 1419602                                 NaN            monthly
# 1419603                                true          irregular
# 1419604  true, true, true, true, true, true          irregular
# 1419605                                true          irregular
# 1419606                                true            monthly
#
#         distribution_model  duration
# 0            field_partner        53
# 1            field_partner        96
# 2            field_partner        37
# 3            field_partner        34
# 4            field_partner        57
# ...                    ...       ...
# 1419602      field_partner        39
# 1419603      field_partner        39
# 1419604      field_partner        51
# 1419605      field_partner        63
# 1419606      field_partner        61
#
# [1419607 rows x 32 columns]

# %% [markdown]
# **3) Find the lenders that have funded at least twice.**

# %%
loanid_status=loans[['loan_id','status']].merge(loan_lenders,'left',on='loan_id')

# %%
loanid_status
# Out:
#           loan_id  status             lenders
# 0          657307  funded         spencer5657
# 1          657307  funded         matthew8640
# 2          657307  funded       larry71496105
# 3          657259  funded                 ltr
# 4          657259  funded          andrew5306
# ...           ...     ...                 ...
# 28326086   989240  funded  jensdamsgaardvanar
# 28326087   989240  funded       david47598776
# 28326088   989240  funded           bernd9221
# 28326089   989240  funded     valeria98599473
# 28326090   989240  funded          donald1853
#
# [28326091 rows x 3 columns]

# %%
count=loanid_status.loc[loanid_status['status']=='funded'].groupby(['lenders'],as_index=False)['loan_id'].count()

# %%
count.loc[count['loan_id']>=2]
# Out:
#                 lenders  loan_id
# 0                   000       39
# 1                 00000       38
# 2                  0002       70
# 4        0101craign0101       71
# 5               0132575        4
# ...                 ...      ...
# 1368254         zzinnia       27
# 1368255      zzivnk7094        4
# 1368256        zzmcfate     1648
# 1368258      zzrvmf8538       13
# 1368259          zzzsai        4
#
# [893981 rows x 2 columns]

# %% [markdown]
# **4) For each country, compute how many loans have involved that country as borrowers.**

# %%
loans.groupby(['country_name'], as_index=False)['loan_id'].count()
# Out:
#       country_name  loan_id
# 0      Afghanistan     2337
# 1          Albania     3075
# 2          Armenia    13952
# 3       Azerbaijan    10172
# 4           Belize      218
# ..             ...      ...
# 91         Vietnam    21839
# 92  Virgin Islands        2
# 93           Yemen     4206
# 94          Zambia     1277
# 95        Zimbabwe     5513
#
# [96 rows x 2 columns]

# %% [markdown]
# **5) For each country, compute the overall amount of money borrowed.**

# %%
country_loan=loans.groupby(['country_name'], as_index=False)['loan_amount'].sum()
country_loan
# Out:
#       country_name  loan_amount
# 0      Afghanistan    1967950.0
# 1          Albania    4307350.0
# 2          Armenia   22950475.0
# 3       Azerbaijan   14784625.0
# 4           Belize     150175.0
# ..             ...          ...
# 91         Vietnam   24681100.0
# 92  Virgin Islands      10000.0
# 93           Yemen    3444000.0
# 94          Zambia    1978975.0
# 95        Zimbabwe    5851875.0
#
# [96 rows x 2 columns]

# %% [markdown]
# **6) Like the previous point, but expressed as a percentage of the overall amount lent.**

# %%
loans.groupby(['country_name'])['loan_amount'].sum()*100/sum(loans.groupby('country_name')['loan_amount'].sum())
# Out:
# country_name
# Afghanistan       0.166573
# Albania           0.364586
# Armenia           1.942589
# Azerbaijan        1.251410
# Belize            0.012711
#                     ...
# Vietnam           2.089074
# Virgin Islands    0.000846
# Yemen             0.291509
# Zambia            0.167506
# Zimbabwe          0.495318
# Name: loan_amount, Length: 96, dtype: float64

# %% [markdown]
# **7) Like the three previous points, but split for each year (with respect to disburse time)**

# %% [markdown]
# **7a) For each country, compute how many loans have involved that country as borrowers.**

# %%
loans.groupby([loans.disburse_time.dt.year.astype('Int64'),'country_name'])['loan_id'].count()
# Out:
# disburse_time  country_name
# 2005           Bulgaria         3
#                Cambodia         2
#                Ecuador         10
#                Gaza             8
#                Honduras        72
#                                ..
# 2018           Tanzania        45
#                Thailand        13
#                Uganda           2
#                Uruguay          1
#                Zambia          14
# Name: loan_id, Length: 748, dtype: int64

# %% [markdown]
# **7b) For each country, compute the overall amount of money borrowed.**

# %%
year_country=loans.groupby([loans.disburse_time.dt.year.astype('Int64'),'country_name'])['loan_amount'].sum().reset_index()
year_country
# Out:
#      disburse_time country_name  loan_amount
# 0             2005     Bulgaria       1850.0
# 1             2005     Cambodia       1625.0
# 2             2005      Ecuador       5000.0
# 3             2005         Gaza       5000.0
# 4             2005     Honduras      33300.0
# ..             ...          ...          ...
# 743           2018     Tanzania      14300.0
# 744           2018     Thailand      26500.0
# 745           2018       Uganda      21750.0
# 746           2018      Uruguay       8000.0
# 747           2018       Zambia      13975.0
#
# [748 rows x 3 columns]

# %% [markdown]
# **7c) Like the previous point, but expressed as a percentage of the overall amount lent.**

# %%
overall_amount_per_year=loans.groupby(loans.disburse_time.dt.year.astype('Int64'), as_index=True)['loan_amount'].sum()
overall_amount_per_year
# Out:
# disburse_time
# 2005       102850.0
# 2006      1376575.0
# 2007     15446525.0
# 2008     39423050.0
# 2009     59689475.0
# 2010     72609150.0
# 2011     93699300.0
# 2012    119977575.0
# 2013    132043925.0
# 2014    152270425.0
# 2015    155835650.0
# 2016    160978375.0
# 2017    166053650.0
# 2018       990025.0
# Name: loan_amount, dtype: float64

# %%
def percentuale(year,loan_tot):
    return loan_tot/overall_amount_per_year[year]*100

# %%
year_country['perc']=year_country.apply(lambda x: percentuale(x['disburse_time'],x['loan_amount']),axis=1)

# %%
year_country
# Out:
#      disburse_time country_name  loan_amount       perc
# 0             2005     Bulgaria       1850.0   1.798736
# 1             2005     Cambodia       1625.0   1.579971
# 2             2005      Ecuador       5000.0   4.861449
# 3             2005         Gaza       5000.0   4.861449
# 4             2005     Honduras      33300.0  32.377248
# ..             ...          ...          ...        ...
# 743           2018     Tanzania      14300.0   1.444408
# 744           2018     Thailand      26500.0   2.676700
# 745           2018       Uganda      21750.0   2.196914
# 746           2018      Uruguay       8000.0   0.808060
# 747           2018       Zambia      13975.0   1.411581
#
# [748 rows x 4 columns]

# %% [markdown]
# **8) For each lender, compute the overall amount of money lent. For each loan that has more than one lender, you must assume that all lenders contributed the same amount.**

# %%
loans['amount_each_lender']=loans['loan_amount']/loans['num_lenders_total']

# %%
loans
# Out:
#          loan_id           loan_name original_language  \
# 0         657307                Aivy           English
# 1         657259      Idalia Marizza           Spanish
# 2         658010               Aasia           English
# 3         659347             Gulmira           Russian
# 4         656933             Ricky\t           English
# ...          ...                 ...               ...
# 1419602   988180                 NaN               NaN
# 1419603   988213             Perlita           English
# 1419604   989109  Okyeso Nyame Group           English
# 1419605   989143            Exequila           English
# 1419606   989240               Lydia            French
#
#                                                description  \
# 0        Aivy, 21 years of age, is single and lives in ...
# 1        Doña Idalia, esta casada, tiene 57 años de eda...
# 2        Aasia is a 45-year-old married lady and she ha...
# 3        Гулмире 36 лет, замужем, вместе с супругом вос...
# 4        Ricky is a farmer who currently cultivates his...
# ...                                                    ...
# 1419602                                                NaN
# 1419603  Perlita is 52 years old, married and has three...
# 1419604  Okyeso Nyame group will begin its third cycle ...
# 1419605  Exequila  is from San Miguel, Bohol. She is in...
# 1419606  Lydia a 37ans et habite dans une zone rurale. ...
#
#                                     description_translated  funded_amount  \
# 0                                                      NaN          125.0
# 1        Idalia, 57, is married and lives with her husb...          400.0
# 2                                                      NaN          400.0
# 3        Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                      NaN          425.0
# ...                                                    ...            ...
# 1419602                                                NaN          400.0
# 1419603  Perlita is 52 years old, married and has three...          300.0
# 1419604  Okyeso Nyame group will begin its third cycle ...         2425.0
# 1419605  Exequila  is from San Miguel, Bohol. She is in...          100.0
# 1419606  Lydia is 37 years old and lives in a rural are...          175.0
#
#          loan_amount  status  activity_name  sector_name  \
# 0              125.0  funded  General Store       Retail
# 1              400.0  funded  Used Clothing     Clothing
# 2              400.0  funded  General Store       Retail
# 3              625.0  funded        Farming  Agriculture
# 4              425.0  funded        Farming  Agriculture
# ...              ...     ...            ...          ...
# 1419602        400.0  funded      Tailoring     Services
# 1419603        300.0  funded           Pigs  Agriculture
# 1419604       2425.0  funded         Bakery         Food
# 1419605        100.0  funded        Farming  Agriculture
# 1419606        175.0  funded         Sewing     Services
#
#                                                   loan_use country_code  \
# 0         to buy additional inventories for her sari-sa...           PH
# 1        To buy American clothing such as blouses, shir...           HN
# 2                    to buy stock of rice, sugar and flour           PK
# 3        to buy cucumber and tomato seeds, as well as f...           KG
# 4         to buy organic fertilizer and agrochemical pr...           PH
# ...                                                    ...          ...
# 1419602                                                NaN           KE
# 1419603  to buy feeds and other supplies to raise her pigs           PH
# 1419604  to buy margarine, flour and sugar at wholesale...           GH
# 1419605                            to buy feed and piglets           PH
# 1419606  to buy a sewing machine, a sewing machine moto...           MG
#
#         country_name                       town_name currency_policy  \
# 0        Philippines            Ozamiz - Ozamiz City          shared
# 1           Honduras               La Lopez, Choloma          shared
# 2           Pakistan                       Lala Musa          shared
# 3         Kyrgyzstan      Aravan village, Osh region          shared
# 4        Philippines  Baleleng, Sto. Thomas, Isabela          shared
# ...              ...                             ...             ...
# 1419602        Kenya                             NaN          shared
# 1419603  Philippines                 Numancia, Aklan          shared
# 1419604        Ghana                         Chorkor          shared
# 1419605  Philippines               San Miguel, Bohol          shared
# 1419606   Madagascar                    Antananarivo          shared
#
#          currency_exchange_coverage_rate currency  partner_id  \
# 0                                    0.1      PHP       126.0
# 1                                    0.1      HNL       201.0
# 2                                    0.1      PKR       245.0
# 3                                    0.1      KGS       171.0
# 4                                    0.1      PHP       123.0
# ...                                  ...      ...         ...
# 1419602                              0.1      KES       138.0
# 1419603                              0.1      PHP       145.0
# 1419604                              0.1      GHS       231.0
# 1419605                              0.1      PHP       125.0
# 1419606                              0.1      MGA       443.0
#
#                            posted_time   planned_expiration_time  \
# 0        2014-01-15 02:23:45.000 +0000 2014-02-14 03:30:06+00:00
# 1        2014-01-14 20:23:20.000 +0000 2014-03-26 22:25:07+00:00
# 2        2014-01-16 11:32:58.000 +0000 2014-02-15 21:10:05+00:00
# 3        2014-01-20 09:59:48.000 +0000 2014-02-21 03:10:02+00:00
# 4        2014-01-14 05:46:21.000 +0000 2014-02-13 06:10:02+00:00
# ...                                ...                       ...
# 1419602  2015-12-01 04:49:50.000 +0000 2016-01-02 01:00:03+00:00
# 1419603  2015-12-01 05:13:30.000 +0000 2016-01-02 16:40:07+00:00
# 1419604  2015-12-02 10:56:28.000 +0000 2016-01-03 22:20:04+00:00
# 1419605  2015-12-02 11:41:46.000 +0000 2016-01-05 08:50:02+00:00
# 1419606  2015-12-02 13:55:07.000 +0000 2016-01-03 20:50:06+00:00
#
#                     disburse_time                    raised_time  lender_term  \
# 0       2013-12-22 08:00:00+00:00  2014-01-15 04:48:22.000 +0000          7.0
# 1       2013-12-20 08:00:00+00:00  2014-02-25 06:42:06.000 +0000          8.0
# 2       2014-01-09 08:00:00+00:00  2014-01-24 23:06:18.000 +0000         14.0
# 3       2014-01-17 08:00:00+00:00  2014-01-22 05:29:28.000 +0000         14.0
# 4       2013-12-17 08:00:00+00:00  2014-01-14 17:29:27.000 +0000          7.0
# ...                           ...                            ...          ...
# 1419602 2015-11-23 08:00:00+00:00  2015-12-28 15:44:18.000 +0000         14.0
# 1419603 2015-11-24 08:00:00+00:00  2015-12-22 10:37:06.000 +0000         14.0
# 1419604 2015-11-13 08:00:00+00:00  2015-12-26 20:24:47.000 +0000          8.0
# 1419605 2015-11-03 08:00:00+00:00  2015-12-06 21:03:57.000 +0000         12.0
# 1419606 2015-11-03 08:00:00+00:00  2015-12-04 23:17:04.000 +0000         14.0
#
#          num_lenders_total  num_journal_entries  num_bulk_entries  \
# 0                        3                    2                 1
# 1                       11                    2                 1
# 2                       16                    2                 1
# 3                       21                    2                 1
# 4                       15                    2                 1
# ...                    ...                  ...               ...
# 1419602                 16                    4                 2
# 1419603                 12                    1                 1
# 1419604                 76                    2                 1
# 1419605                  3                    1                 1
# 1419606                  7                    1                 1
#
#                                                       tags  \
# 0                                                      NaN
# 1                                                      NaN
# 2        #Woman Owned Biz, #Supporting Family, user_fav...
# 3                                            user_favorite
# 4                 #Animals, #Eco-friendly, #Sustainable Ag
# ...                                                    ...
# 1419602        #Parent, #Repeat Borrower, #Woman Owned Biz
# 1419603  #Animals, #Elderly, #Repeat Borrower, #Woman O...
# 1419604  user_favorite, #Parent, #Vegan, #Woman Owned B...
# 1419605                                                NaN
# 1419606                                                NaN
#
#                                    borrower_genders  \
# 0                                            female
# 1                                            female
# 2                                            female
# 3                                            female
# 4                                              male
# ...                                             ...
# 1419602                                         NaN
# 1419603                                      female
# 1419604  female, female, female, male, male, female
# 1419605                                      female
# 1419606                                      female
#
#                           borrower_pictured repayment_interval  \
# 0                                      true          irregular
# 1                                      true            monthly
# 2                                      true            monthly
# 3                                      true            monthly
# 4                                      true             bullet
# ...                                     ...                ...
# 1419602                                 NaN            monthly
# 1419603                                true          irregular
# 1419604  true, true, true, true, true, true          irregular
# 1419605                                true          irregular
# 1419606                                true            monthly
#
#         distribution_model  duration  amount_each_lender
# 0            field_partner        53           41.666667
# 1            field_partner        96           36.363636
# 2            field_partner        37           25.000000
# 3            field_partner        34           29.761905
# 4            field_partner        57           28.333333
# ...                    ...       ...                 ...
# 1419602      field_partner        39           25.000000
# 1419603      field_partner        39           25.000000
# 1419604      field_partner        51           31.907895
# 1419605      field_partner        63           33.333333
# 1419606      field_partner        61           25.000000
#
# [1419607 rows x 33 columns]

# %%
merged_lenders=loans[['loan_id','amount_each_lender']].merge(loan_lenders,'left',on='loan_id')

# %%
merged_lenders
# Out:
#           loan_id  amount_each_lender             lenders
# 0          657307           41.666667         spencer5657
# 1          657307           41.666667         matthew8640
# 2          657307           41.666667       larry71496105
# 3          657259           36.363636                 ltr
# 4          657259           36.363636          andrew5306
# ...           ...                 ...                 ...
# 28326086   989240           25.000000  jensdamsgaardvanar
# 28326087   989240           25.000000       david47598776
# 28326088   989240           25.000000           bernd9221
# 28326089   989240           25.000000     valeria98599473
# 28326090   989240           25.000000          donald1853
#
# [28326091 rows x 3 columns]

# %%
lenders_overall=merged_lenders.groupby(['lenders'],as_index=False)['amount_each_lender'].sum().round(2)
lenders_overall
# Out:
#                 lenders  amount_each_lender
# 0                   000             1563.88
# 1                 00000             1249.95
# 2                  0002             2201.18
# 3              00mike00               38.46
# 4        0101craign0101             2424.09
# ...                 ...                 ...
# 1383794        zzmcfate            60150.83
# 1383795  zzpaghetti9994               44.25
# 1383796      zzrvmf8538              551.83
# 1383797          zzzsai              236.89
# 1383798        zzzworld               26.32
#
# [1383799 rows x 2 columns]

# %% [markdown]
# **9) For each country, compute the difference between the overall amount of money lent and the overall amount of money borrowed. Since the country of the lender is often unknown, you can assume that the true distribution among the countries is the same as the one computed from the rows where the country is known.**

# %%
lenders=pd.read_csv("Files/lenders.csv")

# %%
lenders_country=lenders[['permanent_name','country_code']]
lenders_country.columns=['lenders','country_code']

# %%
s = lenders_country.country_code.value_counts(normalize=True)

# %%
missing = lenders_country['country_code'].isnull()

# %%
lenders_country.loc[missing,'country_code']=np.random.choice(s.index, size=len(lenders_country[missing]), p=s.values)
# Out:
# /Users/martinacecchetto/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/martinacecchetto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lenders_country
# Out:
#                 lenders country_code
# 0              qian3013           US
# 1             reena6733           US
# 2               mai5982           US
# 3        andrew86079135           US
# 4            nguyen6962           US
# ...                 ...          ...
# 2349169       janet7309           US
# 2349170          pj4198           SE
# 2349171       maria2141           US
# 2349172      simone9846           US
# 2349173      laurie1160           US
#
# [2349174 rows x 2 columns]

# %%
country_lended_overall=lenders_overall.merge(lenders_country,'left',on='lenders')
country_lended_overall
# Out:
#                 lenders  amount_each_lender country_code
# 0                   000             1563.88           US
# 1                 00000             1249.95           DE
# 2                  0002             2201.18           US
# 3              00mike00               38.46           TW
# 4        0101craign0101             2424.09           US
# ...                 ...                 ...          ...
# 1383794        zzmcfate            60150.83           US
# 1383795  zzpaghetti9994               44.25           US
# 1383796      zzrvmf8538              551.83           NO
# 1383797          zzzsai              236.89           US
# 1383798        zzzworld               26.32           TC
#
# [1383799 rows x 3 columns]

# %%
country_lended=country_lended_overall.groupby(['country_code'],as_index=False)['amount_each_lender'].sum()
country_lended
# Out:
#     country_code  amount_each_lender
# 0             AD             6113.14
# 1             AE          1756093.29
# 2             AF           147168.93
# 3             AG             2455.89
# 4             AI              500.70
# ..           ...                 ...
# 228           YE            53786.83
# 229           YT              269.79
# 230           ZA           642950.53
# 231           ZM            39472.07
# 232           ZW            15345.27
#
# [233 rows x 2 columns]

# %%
country_borrowed=loans.groupby(['country_code'], as_index=False)['loan_amount'].sum()
country_borrowed
# Out:
#    country_code  loan_amount
# 0            AF    1967950.0
# 1            AL    4307350.0
# 2            AM   22950475.0
# 3            AZ   14784625.0
# 4            BA     477250.0
# ..          ...          ...
# 90           XK    3083025.0
# 91           YE    3444000.0
# 92           ZA    1006525.0
# 93           ZM    1978975.0
# 94           ZW    5851875.0
#
# [95 rows x 2 columns]

# %%
lended_borrowed=country_lended.merge(country_borrowed,'left',on='country_code').fillna(0).round(2)
lended_borrowed.columns=['country_code','amount_lended','amount_borrowed']

# %%
lended_borrowed['difference']=lended_borrowed['amount_lended']-lended_borrowed['amount_borrowed']
lended_borrowed
# Out:
#     country_code  amount_lended  amount_borrowed  difference
# 0             AD        6113.14              0.0     6113.14
# 1             AE     1756093.29              0.0  1756093.29
# 2             AF      147168.93        1967950.0 -1820781.07
# 3             AG        2455.89              0.0     2455.89
# 4             AI         500.70              0.0      500.70
# ..           ...            ...              ...         ...
# 228           YE       53786.83        3444000.0 -3390213.17
# 229           YT         269.79              0.0      269.79
# 230           ZA      642950.53        1006525.0  -363574.47
# 231           ZM       39472.07        1978975.0 -1939502.93
# 232           ZW       15345.27        5851875.0 -5836529.73
#
# [233 rows x 4 columns]

# %% [markdown]
# **10) Which country has the highest ratio between the difference computed at the previous point and the population?**

# %%
country=pd.read_csv("Files/country_stats.csv")

# %%
country_merged=country.merge(lended_borrowed[['country_code','difference']],'left',on='country_code')

# %%
country_merged['ratio_1']=(country_merged['difference']/country_merged['population']).round(2)

# %%
country_merged
# Out:
#                  country_name country_code country_code3 continent  \
# 0                       India           IN           IND      Asia
# 1                     Nigeria           NG           NGA    Africa
# 2                      Mexico           MX           MEX  Americas
# 3                    Pakistan           PK           PAK      Asia
# 4                  Bangladesh           BD           BGD      Asia
# ..                        ...          ...           ...       ...
# 169                   Somalia           SO           SOM    Africa
# 170  Central African Republic           CF           CAF    Africa
# 171                     Samoa           WS           WSM   Oceania
# 172                 Palestine           PS            PS      Asia
# 173                    Kosovo           XK           NaN    Europe
#
#               region  population  population_below_poverty_line       hdi  \
# 0      Southern Asia  1339180127                           21.9  0.623559
# 1     Western Africa   190886311                           70.0  0.527105
# 2    Central America   129163276                           46.2  0.761683
# 3      Southern Asia   197015955                           29.5  0.550354
# 4      Southern Asia   164669751                           31.5  0.578824
# ..               ...         ...                            ...       ...
# 169   Eastern Africa    14742523                            NaN       NaN
# 170    Middle Africa     4659080                            NaN  0.352440
# 171        Polynesia      196440                            NaN  0.702000
# 172     Western Asia     4920724                            NaN  0.677000
# 173  Southern Europe     1895250                           30.0  0.786000
#
#      life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0             68.322                    11.696590                 6.298834
# 1             53.057                     9.970482                 6.000000
# 2             76.972                    13.299090                 8.554985
# 3             66.365                     8.106910                 5.089460
# 4             71.985                    10.178706                 5.241577
# ..               ...                          ...                      ...
# 169              NaN                          NaN                      NaN
# 170           51.458                     7.098980                 4.230000
# 171              NaN                          NaN                      NaN
# 172              NaN                          NaN                      NaN
# 173              NaN                          NaN                      NaN
#
#               gni         kiva_country_name   difference  ratio_1
# 0     5663.474799                     India  -6648128.39    -0.00
# 1     5442.901264                   Nigeria  -7612564.17    -0.04
# 2    16383.106680                    Mexico -23473957.86    -0.18
# 3     5031.173074                  Pakistan -24703601.41    -0.13
# 4     3341.490722                Bangladesh     58779.81     0.00
# ..            ...                       ...          ...      ...
# 169           NaN                   Somalia   -306367.34    -0.02
# 170    587.473961  Central African Republic          NaN      NaN
# 171           NaN                     Samoa -12209825.15   -62.16
# 172           NaN                 Palestine -22248813.89    -4.52
# 173           NaN                    Kosovo  -3069778.85    -1.62
#
# [174 rows x 15 columns]

# %% [markdown]
# Abs Ratio

# %%
maxx=max(abs(country_merged['ratio_1']))

# %%
country_merged.loc[abs(country_merged['ratio_1'])==maxx]
# Out:
#     country_name country_code country_code3 continent     region  population  \
# 171        Samoa           WS           WSM   Oceania  Polynesia      196440
#
#      population_below_poverty_line    hdi  life_expectancy  \
# 171                            NaN  0.702              NaN
#
#      expected_years_of_schooling  mean_years_of_schooling  gni  \
# 171                          NaN                      NaN  NaN
#
#     kiva_country_name   difference  ratio_1
# 171             Samoa -12209825.15   -62.16

# %% [markdown]
# Higher Ratio

# %%
country_merged.iloc[country_merged['ratio_1'].idxmax]
# Out:
# country_name                              Norway
# country_code                                  NO
# country_code3                                NOR
# continent                                 Europe
# region                           Northern Europe
# population                               5305383
# population_below_poverty_line                NaN
# hdi                                     0.949423
# life_expectancy                           81.711
# expected_years_of_schooling              17.6719
# mean_years_of_schooling                  12.7464
# gni                                      67614.4
# kiva_country_name                         Norway
# difference                           1.84693e+07
# ratio_1                                     3.48
# Name: 162, dtype: object

# %% [markdown]
# **11) Which country has the highest ratio between the difference computed at point 9 and the population that is not below the poverty line?**

# %%
country_merged['ratio_2']=(country_merged['difference']/(country_merged['population']*(100-country_merged['population_below_poverty_line']))).round(2)

# %%
country_merged
# Out:
#                  country_name country_code country_code3 continent  \
# 0                       India           IN           IND      Asia
# 1                     Nigeria           NG           NGA    Africa
# 2                      Mexico           MX           MEX  Americas
# 3                    Pakistan           PK           PAK      Asia
# 4                  Bangladesh           BD           BGD      Asia
# ..                        ...          ...           ...       ...
# 169                   Somalia           SO           SOM    Africa
# 170  Central African Republic           CF           CAF    Africa
# 171                     Samoa           WS           WSM   Oceania
# 172                 Palestine           PS            PS      Asia
# 173                    Kosovo           XK           NaN    Europe
#
#               region  population  population_below_poverty_line       hdi  \
# 0      Southern Asia  1339180127                           21.9  0.623559
# 1     Western Africa   190886311                           70.0  0.527105
# 2    Central America   129163276                           46.2  0.761683
# 3      Southern Asia   197015955                           29.5  0.550354
# 4      Southern Asia   164669751                           31.5  0.578824
# ..               ...         ...                            ...       ...
# 169   Eastern Africa    14742523                            NaN       NaN
# 170    Middle Africa     4659080                            NaN  0.352440
# 171        Polynesia      196440                            NaN  0.702000
# 172     Western Asia     4920724                            NaN  0.677000
# 173  Southern Europe     1895250                           30.0  0.786000
#
#      life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0             68.322                    11.696590                 6.298834
# 1             53.057                     9.970482                 6.000000
# 2             76.972                    13.299090                 8.554985
# 3             66.365                     8.106910                 5.089460
# 4             71.985                    10.178706                 5.241577
# ..               ...                          ...                      ...
# 169              NaN                          NaN                      NaN
# 170           51.458                     7.098980                 4.230000
# 171              NaN                          NaN                      NaN
# 172              NaN                          NaN                      NaN
# 173              NaN                          NaN                      NaN
#
#               gni         kiva_country_name   difference  ratio_1  ratio_2
# 0     5663.474799                     India  -6648128.39    -0.00    -0.00
# 1     5442.901264                   Nigeria  -7612564.17    -0.04    -0.00
# 2    16383.106680                    Mexico -23473957.86    -0.18    -0.00
# 3     5031.173074                  Pakistan -24703601.41    -0.13    -0.00
# 4     3341.490722                Bangladesh     58779.81     0.00     0.00
# ..            ...                       ...          ...      ...      ...
# 169           NaN                   Somalia   -306367.34    -0.02      NaN
# 170    587.473961  Central African Republic          NaN      NaN      NaN
# 171           NaN                     Samoa -12209825.15   -62.16      NaN
# 172           NaN                 Palestine -22248813.89    -4.52      NaN
# 173           NaN                    Kosovo  -3069778.85    -1.62    -0.02
#
# [174 rows x 16 columns]

# %%
maxx=max(abs(country_merged['ratio_2']))

# %%
country_merged.loc[abs(country_merged['ratio_2'])==maxx]
# Out:
#     country_name country_code country_code3 continent        region  \
# 109      Armenia           AM           ARM      Asia  Western Asia
#
#      population  population_below_poverty_line      hdi  life_expectancy  \
# 109     2930450                           32.0  0.74285           74.886
#
#      expected_years_of_schooling  mean_years_of_schooling          gni  \
# 109                    12.713218                 11.29105  8189.115193
#
#     kiva_country_name  difference  ratio_1  ratio_2
# 109           Armenia -22916900.0    -7.82    -0.12

# %% [markdown]
# Higher Ratio

# %%
country_merged.iloc[country_merged['ratio_2'].idxmax]
# Out:
# country_name                               Canada
# country_code                                   CA
# country_code3                                 CAN
# continent                                Americas
# region                           Northern America
# population                               36624199
# population_below_poverty_line                 9.4
# hdi                                      0.920284
# life_expectancy                            82.224
# expected_years_of_schooling                16.325
# mean_years_of_schooling                   13.1051
# gni                                       42581.9
# kiva_country_name                          Canada
# difference                             8.4099e+07
# ratio_1                                       2.3
# ratio_2                                      0.03
# Name: 72, dtype: object

# %% [markdown]
# **12) For each year, compute the total amount of loans. Each loan that has planned expiration time and disburse time in different years must have its amount distributed proportionally to the number of days in each year. For example, a loan with disburse time December 1st, 2016, planned expiration time January 30th 2018, and amount 5000USD has an amount of 5000USD * 31 / (31+365+30) = 363.85 for 2016, 5000USD * 365 / (31+365+30) = 4284.04 for 2017, and 5000USD * 30 / (31+365+30) = 352.11 for 2018.**

# %%
loans_final=loans[['loan_id','disburse_time','planned_expiration_time','duration','loan_amount']].dropna()

# %%
def create_list(start,end):
    return list(range(start,end+1))

# %%
loans_final['years']=loans_final.apply(lambda x: create_list(x['disburse_time'].year,x['planned_expiration_time'].year),axis=1)

# %%
loans_final=loans_final.explode('years').reset_index(drop=True).dropna()
loans_final
# Out:
#          loan_id             disburse_time   planned_expiration_time  \
# 0         657307 2013-12-22 08:00:00+00:00 2014-02-14 03:30:06+00:00
# 1         657307 2013-12-22 08:00:00+00:00 2014-02-14 03:30:06+00:00
# 2         657259 2013-12-20 08:00:00+00:00 2014-03-26 22:25:07+00:00
# 3         657259 2013-12-20 08:00:00+00:00 2014-03-26 22:25:07+00:00
# 4         658010 2014-01-09 08:00:00+00:00 2014-02-15 21:10:05+00:00
# ...          ...                       ...                       ...
# 1196549   989109 2015-11-13 08:00:00+00:00 2016-01-03 22:20:04+00:00
# 1196550   989143 2015-11-03 08:00:00+00:00 2016-01-05 08:50:02+00:00
# 1196551   989143 2015-11-03 08:00:00+00:00 2016-01-05 08:50:02+00:00
# 1196552   989240 2015-11-03 08:00:00+00:00 2016-01-03 20:50:06+00:00
# 1196553   989240 2015-11-03 08:00:00+00:00 2016-01-03 20:50:06+00:00
#
#          duration  loan_amount years
# 0              53        125.0  2013
# 1              53        125.0  2014
# 2              96        400.0  2013
# 3              96        400.0  2014
# 4              37        400.0  2014
# ...           ...          ...   ...
# 1196549        51       2425.0  2016
# 1196550        63        100.0  2015
# 1196551        63        100.0  2016
# 1196552        61        175.0  2015
# 1196553        61        175.0  2016
#
# [1195008 rows x 6 columns]

# %%
loans_final.loc[loans_final.duration==0]
# Out:
#          loan_id             disburse_time   planned_expiration_time  \
# 4269      566282 2013-06-28 07:00:00+00:00 2013-06-28 17:10:02+00:00
# 6305      528542 2013-03-19 07:00:00+00:00 2013-03-19 22:00:04+00:00
# 9948     1387345 2017-11-01 07:00:00+00:00 2017-11-01 22:20:04+00:00
# 10162    1000466 2016-02-01 08:00:00+00:00 2016-02-01 18:10:02+00:00
# 10250     998891 2016-01-22 08:00:00+00:00 2016-01-22 21:30:16+00:00
# ...          ...                       ...                       ...
# 1181938   806824 2015-02-01 08:00:00+00:00 2015-02-02 00:20:52+00:00
# 1182996  1097208 2016-07-15 07:00:00+00:00 2016-07-15 19:00:08+00:00
# 1191215   561988 2013-06-21 07:00:00+00:00 2013-06-21 09:00:03+00:00
# 1191468   867784 2015-05-14 07:00:00+00:00 2015-05-15 02:50:05+00:00
# 1193653  1067062 2016-06-11 07:00:00+00:00 2016-06-11 18:50:06+00:00
#
#          duration  loan_amount years
# 4269            0        500.0  2013
# 6305            0        250.0  2013
# 9948            0        950.0  2017
# 10162           0        450.0  2016
# 10250           0       1100.0  2016
# ...           ...          ...   ...
# 1181938         0       1625.0  2015
# 1182996         0        600.0  2016
# 1191215         0        400.0  2013
# 1191468         0       3500.0  2015
# 1193653         0       1750.0  2016
#
# [772 rows x 6 columns]

# %%
def amount_per_year(year, disburse_time, planned_expiration_time, loan_amount, duration):
    
    
    if (disburse_time.year == planned_expiration_time.year):
            return loan_amount
    
    amount_per_day=loan_amount/duration
    
    if (year == disburse_time.year):
            end_year=datetime.date(year, 12, 31)
            duration=(end_year-disburse_time.date()).days
            return amount_per_day*duration
        
    elif (year == planned_expiration_time.year):
            start_year=datetime.date(year, 1, 1)
            duration=(planned_expiration_time.date()-start_year).days
            return amount_per_day*duration
        
    else:
        duration=(datetime.date(year, 12, 31) - datetime.date(year, 1, 1)).days   
        return amount_per_day*duration

# %%
loans_final['amount_year']=loans_final.apply(lambda x: amount_per_year(x['years'],x['disburse_time'],x['planned_expiration_time'],x['loan_amount'], x['duration']),axis=1)

# %%
loans_final
# Out:
#          loan_id             disburse_time   planned_expiration_time  \
# 0         657307 2013-12-22 08:00:00+00:00 2014-02-14 03:30:06+00:00
# 1         657307 2013-12-22 08:00:00+00:00 2014-02-14 03:30:06+00:00
# 2         657259 2013-12-20 08:00:00+00:00 2014-03-26 22:25:07+00:00
# 3         657259 2013-12-20 08:00:00+00:00 2014-03-26 22:25:07+00:00
# 4         658010 2014-01-09 08:00:00+00:00 2014-02-15 21:10:05+00:00
# ...          ...                       ...                       ...
# 1196549   989109 2015-11-13 08:00:00+00:00 2016-01-03 22:20:04+00:00
# 1196550   989143 2015-11-03 08:00:00+00:00 2016-01-05 08:50:02+00:00
# 1196551   989143 2015-11-03 08:00:00+00:00 2016-01-05 08:50:02+00:00
# 1196552   989240 2015-11-03 08:00:00+00:00 2016-01-03 20:50:06+00:00
# 1196553   989240 2015-11-03 08:00:00+00:00 2016-01-03 20:50:06+00:00
#
#          duration  loan_amount years  amount_year
# 0              53        125.0  2013    21.226415
# 1              53        125.0  2014   103.773585
# 2              96        400.0  2013    45.833333
# 3              96        400.0  2014   350.000000
# 4              37        400.0  2014   400.000000
# ...           ...          ...   ...          ...
# 1196549        51       2425.0  2016    95.098039
# 1196550        63        100.0  2015    92.063492
# 1196551        63        100.0  2016     6.349206
# 1196552        61        175.0  2015   166.393443
# 1196553        61        175.0  2016     5.737705
#
# [1195008 rows x 7 columns]

# %%
loans_final.groupby(['years'],as_index=False)['amount_year'].sum().round(1)
# Out:
#    years  amount_year
# 0   2011     631678.3
# 1   2012  113276495.2
# 2   2013  124740262.0
# 3   2014  152832884.3
# 4   2015  159409307.9
# 5   2016  158704830.6
# 6   2017  171523233.5
# 7   2018    5421198.4
